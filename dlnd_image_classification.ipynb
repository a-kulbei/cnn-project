# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    return x / 255


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    res = np.zeros((len(x), 10))
    for i in range(len(x)):
        res[i][x[i]] = 1
        
    return res

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, image_shape[0], image_shape[1], image_shape[2]], name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, n_classes], name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    print(x_tensor.get_shape().as_list())
    print(conv_strides)

    x_shape = x_tensor.get_shape().as_list()
    weight = tf.Variable(tf.truncated_normal([conv_ksize[0], conv_ksize[1], x_shape[3], conv_num_outputs], mean=0.0, stddev=0.1))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    # conv layer
    conv_layer = tf.nn.conv2d(x_tensor, weight, [1, conv_strides[0], conv_strides[1], 1], padding='SAME')
    # add bias
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    # relu
    conv_layer = tf.nn.relu(conv_layer)
    # max pooling
    conv_layer = tf.nn.max_pool(conv_layer,
                                ksize=[1, pool_ksize[0], pool_ksize[1], 1],
                                strides=[1, pool_strides[0], pool_strides[1], 1],
                                padding='SAME')
    
    return conv_layer 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# [None, 32, 32, 5]
# (4, 4)
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function

#     x_shape = x_tensor.get_shape().as_list()

#     flattened_image_size = x_shape[1] * x_shape[2] * x_shape[3]
#     return tf.reshape(x_tensor, [-1, flattened_image_size])
    return tf.contrib.layers.flatten(x_tensor)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    x_shape = x_tensor.get_shape().as_list()
    weight = tf.Variable(tf.random_normal([x_shape[1], num_outputs], stddev=0.1))
    bias = tf.Variable(tf.random_normal([num_outputs]))

    fc = tf.add(tf.matmul(x_tensor, weight), bias)
    fc = tf.nn.relu(fc)
    # TODO: Implement Function
    return fc


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    x_shape = x_tensor.get_shape().as_list()
    weight = tf.Variable(tf.random_normal([x_shape[1], num_outputs], stddev=0.1))
    bias = tf.Variable(tf.random_normal([num_outputs]))

    fc = tf.add(tf.matmul(x_tensor, weight), bias)
    # TODO: Implement Function
    return fc


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)

    print(x.get_shape().as_list())
    # Hyperparameters
    # we have 10 possible classes
#     conv_num_outputs = 10
    # size of kernel
    conv_ksize = (3, 3)
    conv_strides = (1, 1)
    pool_ksize = (2, 2)
    pool_strides = (1, 1)
    
#     conv_num_outputs = int((32 - conv_ksize[0] + 2)/conv_strides[1] + 1)
    conv_num_outputs = 16
    print(conv_num_outputs)
    
    nnet = conv2d_maxpool(x, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    print('shape of first layer')
    print(nnet.get_shape().as_list())
    nnet = conv2d_maxpool(nnet, conv_num_outputs * 2, conv_ksize, conv_strides, pool_ksize, pool_strides)

#     nnet = conv2d_maxpool(nnet, 32, conv_ksize, conv_strides, pool_ksize, pool_strides)
#     conv3 = conv2d_maxpool(conv2, 64, conv_ksize, conv_strides, pool_ksize, pool_strides)
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    nnet = flatten(nnet)
    print(nnet.get_shape())
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    nnet = fully_conn(nnet, 100)
    nnet = tf.nn.dropout(nnet, keep_prob)
#     nnet = fully_conn(nnet, 100)
#     nnet = fully_conn(nnet, 60)
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    out = output(nnet, 10)
    
    
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# [None, 32, 32, 3]
# 16
# [None, 32, 32, 3]
# (1, 1)
# shape of first layer
# [None, 32, 32, 16]
# [None, 32, 32, 16]
# (1, 1)
# (?, 32768)
# [None, 32, 32, 3]
# 16
# [None, 32, 32, 3]
# (1, 1)
# shape of first layer
# [None, 32, 32, 16]
# [None, 32, 32, 16]
# (1, 1)
# (?, 32768)
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={
        x: feature_batch,
        y: label_batch,
        keep_prob: keep_probability
    })


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    loss = session.run(cost, feed_dict={
        x: feature_batch,
        y: label_batch,
        keep_prob: 1.0
    })
    valid_acc = session.run(accuracy, feed_dict={
        x: valid_features,
        y: valid_labels,
        keep_prob: 1.0
    })
    print("Loss: {:>10.4f} Validation Accuracy: {:.6f}".format(loss, valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 200
keep_probability = 0.4

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.1108 Validation Accuracy: 0.255200
# Epoch  1, CIFAR-10 Batch 2:  Loss:     1.7561 Validation Accuracy: 0.397800
# Epoch  1, CIFAR-10 Batch 3:  Loss:     1.5527 Validation Accuracy: 0.437400
# Epoch  1, CIFAR-10 Batch 4:  Loss:     1.5490 Validation Accuracy: 0.432600
# Epoch  1, CIFAR-10 Batch 5:  Loss:     1.5248 Validation Accuracy: 0.479800
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.5379 Validation Accuracy: 0.499000
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.4195 Validation Accuracy: 0.491000
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.3360 Validation Accuracy: 0.479600
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.3723 Validation Accuracy: 0.482400
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.3163 Validation Accuracy: 0.519200
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.3649 Validation Accuracy: 0.536200
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.2901 Validation Accuracy: 0.535400
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.1158 Validation Accuracy: 0.545600
# Epoch  3, CIFAR-10 Batch 4:  Loss:     1.1843 Validation Accuracy: 0.548000
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.1722 Validation Accuracy: 0.561800
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.2631 Validation Accuracy: 0.538200
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.2010 Validation Accuracy: 0.564000
# Epoch  4, CIFAR-10 Batch 3:  Loss:     1.0241 Validation Accuracy: 0.575400
# Epoch  4, CIFAR-10 Batch 4:  Loss:     1.1274 Validation Accuracy: 0.578000
# Epoch  4, CIFAR-10 Batch 5:  Loss:     1.1264 Validation Accuracy: 0.590400
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.1491 Validation Accuracy: 0.584400
# Epoch  5, CIFAR-10 Batch 2:  Loss:     1.0920 Validation Accuracy: 0.584000
# Epoch  5, CIFAR-10 Batch 3:  Loss:     0.9475 Validation Accuracy: 0.592600
# Epoch  5, CIFAR-10 Batch 4:  Loss:     1.0807 Validation Accuracy: 0.585800
# Epoch  5, CIFAR-10 Batch 5:  Loss:     1.0309 Validation Accuracy: 0.602400
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.1177 Validation Accuracy: 0.594400
# Epoch  6, CIFAR-10 Batch 2:  Loss:     1.0178 Validation Accuracy: 0.606800
# Epoch  6, CIFAR-10 Batch 3:  Loss:     0.8945 Validation Accuracy: 0.598600
# Epoch  6, CIFAR-10 Batch 4:  Loss:     1.0016 Validation Accuracy: 0.612800
# Epoch  6, CIFAR-10 Batch 5:  Loss:     0.9800 Validation Accuracy: 0.611000
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.0305 Validation Accuracy: 0.606400
# Epoch  7, CIFAR-10 Batch 2:  Loss:     0.9633 Validation Accuracy: 0.612800
# Epoch  7, CIFAR-10 Batch 3:  Loss:     0.8675 Validation Accuracy: 0.607400
# Epoch  7, CIFAR-10 Batch 4:  Loss:     0.9490 Validation Accuracy: 0.613000
# Epoch  7, CIFAR-10 Batch 5:  Loss:     0.9221 Validation Accuracy: 0.619000
# Epoch  8, CIFAR-10 Batch 1:  Loss:     0.9656 Validation Accuracy: 0.613400
# Epoch  8, CIFAR-10 Batch 2:  Loss:     0.9009 Validation Accuracy: 0.625000
# Epoch  8, CIFAR-10 Batch 3:  Loss:     0.8246 Validation Accuracy: 0.613400
# Epoch  8, CIFAR-10 Batch 4:  Loss:     0.8886 Validation Accuracy: 0.613400
# Epoch  8, CIFAR-10 Batch 5:  Loss:     0.9287 Validation Accuracy: 0.623400
# Epoch  9, CIFAR-10 Batch 1:  Loss:     0.9321 Validation Accuracy: 0.613000
# Epoch  9, CIFAR-10 Batch 2:  Loss:     0.8512 Validation Accuracy: 0.634400
# Epoch  9, CIFAR-10 Batch 3:  Loss:     0.7498 Validation Accuracy: 0.629800
# Epoch  9, CIFAR-10 Batch 4:  Loss:     0.8506 Validation Accuracy: 0.625200
# Epoch  9, CIFAR-10 Batch 5:  Loss:     0.8453 Validation Accuracy: 0.640400
# Epoch 10, CIFAR-10 Batch 1:  Loss:     0.9123 Validation Accuracy: 0.628000
# Epoch 10, CIFAR-10 Batch 2:  Loss:     0.8304 Validation Accuracy: 0.627800
# Epoch 10, CIFAR-10 Batch 3:  Loss:     0.7503 Validation Accuracy: 0.626600
# Epoch 10, CIFAR-10 Batch 4:  Loss:     0.8020 Validation Accuracy: 0.640200
# Epoch 10, CIFAR-10 Batch 5:  Loss:     0.7751 Validation Accuracy: 0.642800
# Epoch 11, CIFAR-10 Batch 1:  Loss:     0.8416 Validation Accuracy: 0.645200
# Epoch 11, CIFAR-10 Batch 2:  Loss:     0.7777 Validation Accuracy: 0.649800
# Epoch 11, CIFAR-10 Batch 3:  Loss:     0.6858 Validation Accuracy: 0.646600
# Epoch 11, CIFAR-10 Batch 4:  Loss:     0.7718 Validation Accuracy: 0.641000
# Epoch 11, CIFAR-10 Batch 5:  Loss:     0.7470 Validation Accuracy: 0.644200
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.8294 Validation Accuracy: 0.649200
# Epoch 12, CIFAR-10 Batch 2:  Loss:     0.7451 Validation Accuracy: 0.639000
# Epoch 12, CIFAR-10 Batch 3:  Loss:     0.6794 Validation Accuracy: 0.639200
# Epoch 12, CIFAR-10 Batch 4:  Loss:     0.7192 Validation Accuracy: 0.656000
# Epoch 12, CIFAR-10 Batch 5:  Loss:     0.6934 Validation Accuracy: 0.654800
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.7974 Validation Accuracy: 0.654800
# Epoch 13, CIFAR-10 Batch 2:  Loss:     0.7253 Validation Accuracy: 0.655800
# Epoch 13, CIFAR-10 Batch 3:  Loss:     0.6348 Validation Accuracy: 0.647800
# Epoch 13, CIFAR-10 Batch 4:  Loss:     0.7010 Validation Accuracy: 0.647600
# Epoch 13, CIFAR-10 Batch 5:  Loss:     0.6862 Validation Accuracy: 0.656200
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.7672 Validation Accuracy: 0.640200
# Epoch 14, CIFAR-10 Batch 2:  Loss:     0.7183 Validation Accuracy: 0.633600
# Epoch 14, CIFAR-10 Batch 3:  Loss:     0.6300 Validation Accuracy: 0.642600
# Epoch 14, CIFAR-10 Batch 4:  Loss:     0.6572 Validation Accuracy: 0.654600
# Epoch 14, CIFAR-10 Batch 5:  Loss:     0.6727 Validation Accuracy: 0.652200
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.7372 Validation Accuracy: 0.651600
# Epoch 15, CIFAR-10 Batch 2:  Loss:     0.6546 Validation Accuracy: 0.651000
# Epoch 15, CIFAR-10 Batch 3:  Loss:     0.5754 Validation Accuracy: 0.656000
# Epoch 15, CIFAR-10 Batch 4:  Loss:     0.6535 Validation Accuracy: 0.653400
# Epoch 15, CIFAR-10 Batch 5:  Loss:     0.6151 Validation Accuracy: 0.663200
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.6566 Validation Accuracy: 0.649400
# Epoch 16, CIFAR-10 Batch 2:  Loss:     0.6350 Validation Accuracy: 0.653200
# Epoch 16, CIFAR-10 Batch 3:  Loss:     0.5607 Validation Accuracy: 0.656800
# Epoch 16, CIFAR-10 Batch 4:  Loss:     0.6707 Validation Accuracy: 0.658200
# Epoch 16, CIFAR-10 Batch 5:  Loss:     0.5964 Validation Accuracy: 0.661200
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.6545 Validation Accuracy: 0.664200
# Epoch 17, CIFAR-10 Batch 2:  Loss:     0.6246 Validation Accuracy: 0.657800
# Epoch 17, CIFAR-10 Batch 3:  Loss:     0.5700 Validation Accuracy: 0.650000
# Epoch 17, CIFAR-10 Batch 4:  Loss:     0.6198 Validation Accuracy: 0.654600
# Epoch 17, CIFAR-10 Batch 5:  Loss:     0.5576 Validation Accuracy: 0.658600
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.6157 Validation Accuracy: 0.655400
# Epoch 18, CIFAR-10 Batch 2:  Loss:     0.5932 Validation Accuracy: 0.661400
# Epoch 18, CIFAR-10 Batch 3:  Loss:     0.5485 Validation Accuracy: 0.648000
# Epoch 18, CIFAR-10 Batch 4:  Loss:     0.5711 Validation Accuracy: 0.661800
# Epoch 18, CIFAR-10 Batch 5:  Loss:     0.5844 Validation Accuracy: 0.653000
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.6387 Validation Accuracy: 0.650800
# Epoch 19, CIFAR-10 Batch 2:  Loss:     0.5668 Validation Accuracy: 0.665400
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.5187 Validation Accuracy: 0.658600
# Epoch 19, CIFAR-10 Batch 4:  Loss:     0.5711 Validation Accuracy: 0.660200
# Epoch 19, CIFAR-10 Batch 5:  Loss:     0.5214 Validation Accuracy: 0.661800
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.6086 Validation Accuracy: 0.643000
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.5150 Validation Accuracy: 0.665200
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.4579 Validation Accuracy: 0.656200
# Epoch 20, CIFAR-10 Batch 4:  Loss:     0.5454 Validation Accuracy: 0.666800
# Epoch 20, CIFAR-10 Batch 5:  Loss:     0.4804 Validation Accuracy: 0.664200
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.5743 Validation Accuracy: 0.646600
# Epoch 21, CIFAR-10 Batch 2:  Loss:     0.4927 Validation Accuracy: 0.655800
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.4505 Validation Accuracy: 0.656600
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.5008 Validation Accuracy: 0.663600
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.4512 Validation Accuracy: 0.665600
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.5687 Validation Accuracy: 0.650800
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.4765 Validation Accuracy: 0.664200
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.4097 Validation Accuracy: 0.652200
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.5092 Validation Accuracy: 0.654200
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.4583 Validation Accuracy: 0.673800
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.5380 Validation Accuracy: 0.644600
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.4772 Validation Accuracy: 0.664200
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.4192 Validation Accuracy: 0.650800
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.4747 Validation Accuracy: 0.652200
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.4437 Validation Accuracy: 0.664600
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.5095 Validation Accuracy: 0.660200
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.4453 Validation Accuracy: 0.656600
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.3766 Validation Accuracy: 0.658400
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.4300 Validation Accuracy: 0.662200
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.4252 Validation Accuracy: 0.661800
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.4722 Validation Accuracy: 0.660200
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.5183 Validation Accuracy: 0.642600
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.3693 Validation Accuracy: 0.654000
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.4290 Validation Accuracy: 0.651400
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.3851 Validation Accuracy: 0.662800
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.4473 Validation Accuracy: 0.661000
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.4314 Validation Accuracy: 0.646400
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.3588 Validation Accuracy: 0.664000
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.4086 Validation Accuracy: 0.658400
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.4018 Validation Accuracy: 0.659000
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.4024 Validation Accuracy: 0.660600
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.4150 Validation Accuracy: 0.647600
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.3172 Validation Accuracy: 0.657400
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.3567 Validation Accuracy: 0.658000
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.3556 Validation Accuracy: 0.663600
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.3784 Validation Accuracy: 0.670000
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.3603 Validation Accuracy: 0.653800
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.3317 Validation Accuracy: 0.648400
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.3820 Validation Accuracy: 0.647400
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.3158 Validation Accuracy: 0.666400
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.3960 Validation Accuracy: 0.661200
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.3521 Validation Accuracy: 0.658800
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.2997 Validation Accuracy: 0.651800
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.3439 Validation Accuracy: 0.653400
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.3066 Validation Accuracy: 0.674200
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.3604 Validation Accuracy: 0.666600
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.3256 Validation Accuracy: 0.663400
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.2836 Validation Accuracy: 0.658600
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.3013 Validation Accuracy: 0.660000
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.2976 Validation Accuracy: 0.667600
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.3500 Validation Accuracy: 0.670400
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.3006 Validation Accuracy: 0.662200
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.2724 Validation Accuracy: 0.657600
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.2795 Validation Accuracy: 0.657800
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.2522 Validation Accuracy: 0.675000
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.3412 Validation Accuracy: 0.664400
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.3116 Validation Accuracy: 0.664800
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.2572 Validation Accuracy: 0.662400
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.2719 Validation Accuracy: 0.645800
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.2696 Validation Accuracy: 0.658200
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.3160 Validation Accuracy: 0.661800
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.2977 Validation Accuracy: 0.664800
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.2538 Validation Accuracy: 0.660600
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.2767 Validation Accuracy: 0.654600
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.2485 Validation Accuracy: 0.670000
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.3049 Validation Accuracy: 0.662000
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.2869 Validation Accuracy: 0.659400
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.2147 Validation Accuracy: 0.657800
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.2482 Validation Accuracy: 0.656000
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.2360 Validation Accuracy: 0.666200
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.2853 Validation Accuracy: 0.660000
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.2659 Validation Accuracy: 0.656800
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.2020 Validation Accuracy: 0.667800
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.2428 Validation Accuracy: 0.656200
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.2232 Validation Accuracy: 0.666200
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.2588 Validation Accuracy: 0.657400
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.2673 Validation Accuracy: 0.662600
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.2003 Validation Accuracy: 0.666600
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.2229 Validation Accuracy: 0.660400
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.2035 Validation Accuracy: 0.665400
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.2285 Validation Accuracy: 0.658800
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.2443 Validation Accuracy: 0.657200
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.2101 Validation Accuracy: 0.663000
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.1968 Validation Accuracy: 0.651400
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.2126 Validation Accuracy: 0.668000
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.2228 Validation Accuracy: 0.665800
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.2252 Validation Accuracy: 0.661000
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.1789 Validation Accuracy: 0.667600
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.2046 Validation Accuracy: 0.657000
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.1939 Validation Accuracy: 0.656200
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.2276 Validation Accuracy: 0.657600
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.2260 Validation Accuracy: 0.648200
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.1778 Validation Accuracy: 0.662000
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.2117 Validation Accuracy: 0.650800
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.1888 Validation Accuracy: 0.658800
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.2084 Validation Accuracy: 0.661800
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.2352 Validation Accuracy: 0.646400
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.1725 Validation Accuracy: 0.662600
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.2035 Validation Accuracy: 0.653600
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.1715 Validation Accuracy: 0.663600
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.2100 Validation Accuracy: 0.658800
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.2018 Validation Accuracy: 0.656000
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.1459 Validation Accuracy: 0.665800
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.1939 Validation Accuracy: 0.651000
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.1742 Validation Accuracy: 0.658000
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.1976 Validation Accuracy: 0.657800
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.2075 Validation Accuracy: 0.649000
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.1644 Validation Accuracy: 0.662400
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.1870 Validation Accuracy: 0.649000
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.1496 Validation Accuracy: 0.663600
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.1983 Validation Accuracy: 0.657200
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.1918 Validation Accuracy: 0.657800
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.1425 Validation Accuracy: 0.664400
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.1992 Validation Accuracy: 0.652400
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.1528 Validation Accuracy: 0.664800
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.1945 Validation Accuracy: 0.655800
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.1729 Validation Accuracy: 0.656600
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.1610 Validation Accuracy: 0.662400
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.1833 Validation Accuracy: 0.652000
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.1360 Validation Accuracy: 0.664800
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.2030 Validation Accuracy: 0.655600
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.1553 Validation Accuracy: 0.657200
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.1317 Validation Accuracy: 0.663800
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.1778 Validation Accuracy: 0.656400
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.1409 Validation Accuracy: 0.664000
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.1730 Validation Accuracy: 0.655000
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.1603 Validation Accuracy: 0.650000
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.1375 Validation Accuracy: 0.660000
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.1798 Validation Accuracy: 0.657000
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.1379 Validation Accuracy: 0.660800
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.1910 Validation Accuracy: 0.646000
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.1353 Validation Accuracy: 0.660600
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.1286 Validation Accuracy: 0.661600
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.1559 Validation Accuracy: 0.653800
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.1551 Validation Accuracy: 0.654400
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.1426 Validation Accuracy: 0.642200
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.1737 Validation Accuracy: 0.648000
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.1243 Validation Accuracy: 0.655600
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.1382 Validation Accuracy: 0.660200
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.1689 Validation Accuracy: 0.649600
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.1630 Validation Accuracy: 0.647600
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.1406 Validation Accuracy: 0.656000
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.0944 Validation Accuracy: 0.660600
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.1467 Validation Accuracy: 0.660000
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.1215 Validation Accuracy: 0.662800
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.1623 Validation Accuracy: 0.646200
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.1439 Validation Accuracy: 0.652800
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.1025 Validation Accuracy: 0.661400
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.1307 Validation Accuracy: 0.658800
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.1339 Validation Accuracy: 0.656000
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.1469 Validation Accuracy: 0.652200
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.1508 Validation Accuracy: 0.644800
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.1099 Validation Accuracy: 0.667000
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.1260 Validation Accuracy: 0.660400
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.1249 Validation Accuracy: 0.651400
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.1445 Validation Accuracy: 0.654000
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.1345 Validation Accuracy: 0.652600
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.0960 Validation Accuracy: 0.664800
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.1291 Validation Accuracy: 0.659600
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.1144 Validation Accuracy: 0.651600
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.1235 Validation Accuracy: 0.652400
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.1195 Validation Accuracy: 0.651800
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.1048 Validation Accuracy: 0.657200
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.1137 Validation Accuracy: 0.650200
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.1217 Validation Accuracy: 0.653800
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.1371 Validation Accuracy: 0.650400
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.1114 Validation Accuracy: 0.650800
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.1024 Validation Accuracy: 0.660200
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.1172 Validation Accuracy: 0.660000
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.1181 Validation Accuracy: 0.645800
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.1197 Validation Accuracy: 0.653400
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.0944 Validation Accuracy: 0.650000
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.0963 Validation Accuracy: 0.657000
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.1164 Validation Accuracy: 0.654600
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.1083 Validation Accuracy: 0.657000
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.1191 Validation Accuracy: 0.645200
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.1007 Validation Accuracy: 0.647400
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.1035 Validation Accuracy: 0.656800
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.1059 Validation Accuracy: 0.655600
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.1069 Validation Accuracy: 0.653000
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.1059 Validation Accuracy: 0.648400
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.0824 Validation Accuracy: 0.654200
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.0911 Validation Accuracy: 0.658600
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.1168 Validation Accuracy: 0.652200
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.0869 Validation Accuracy: 0.656000
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.0910 Validation Accuracy: 0.656400
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.0764 Validation Accuracy: 0.653600
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.0852 Validation Accuracy: 0.658200
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.0994 Validation Accuracy: 0.650600
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.0857 Validation Accuracy: 0.659400
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.1092 Validation Accuracy: 0.640800
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.0625 Validation Accuracy: 0.655200
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.0784 Validation Accuracy: 0.654400
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.0994 Validation Accuracy: 0.649200
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.0941 Validation Accuracy: 0.651600
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.0947 Validation Accuracy: 0.647400
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.0742 Validation Accuracy: 0.651600
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.0877 Validation Accuracy: 0.658600
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.0930 Validation Accuracy: 0.647400
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.1060 Validation Accuracy: 0.653600
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.1123 Validation Accuracy: 0.648800
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.0712 Validation Accuracy: 0.656600
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.0879 Validation Accuracy: 0.661200
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.0837 Validation Accuracy: 0.642600
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.0995 Validation Accuracy: 0.657000
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.0987 Validation Accuracy: 0.644400
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.0787 Validation Accuracy: 0.657000
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.0869 Validation Accuracy: 0.657000
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.0832 Validation Accuracy: 0.655400
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.0980 Validation Accuracy: 0.650800
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.0953 Validation Accuracy: 0.642800
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.0674 Validation Accuracy: 0.655600
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.0650 Validation Accuracy: 0.661200
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.0738 Validation Accuracy: 0.648800
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.1146 Validation Accuracy: 0.639200
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.0861 Validation Accuracy: 0.644800
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.0563 Validation Accuracy: 0.658800
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.0865 Validation Accuracy: 0.657200
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.0696 Validation Accuracy: 0.655600
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.0976 Validation Accuracy: 0.651000
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.0830 Validation Accuracy: 0.653200
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.0602 Validation Accuracy: 0.655800
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.0551 Validation Accuracy: 0.657800
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.0635 Validation Accuracy: 0.657400
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.0949 Validation Accuracy: 0.637000
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.0768 Validation Accuracy: 0.648000
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.0623 Validation Accuracy: 0.645600
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.0772 Validation Accuracy: 0.659600
# Epoch 66, CIFAR-10 Batch 4:  Loss:     0.0622 Validation Accuracy: 0.660400
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.0889 Validation Accuracy: 0.647800
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.0881 Validation Accuracy: 0.643800
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.0529 Validation Accuracy: 0.656200
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.0789 Validation Accuracy: 0.658000
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.0636 Validation Accuracy: 0.654600
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.0710 Validation Accuracy: 0.649200
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.0785 Validation Accuracy: 0.643600
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.0538 Validation Accuracy: 0.652400
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.0514 Validation Accuracy: 0.659000
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.0618 Validation Accuracy: 0.652400
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.0881 Validation Accuracy: 0.649800
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.0728 Validation Accuracy: 0.651600
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.0513 Validation Accuracy: 0.651600
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.0681 Validation Accuracy: 0.654800
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.0704 Validation Accuracy: 0.645600
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.0796 Validation Accuracy: 0.655200
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.0727 Validation Accuracy: 0.653000
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.0520 Validation Accuracy: 0.655200
# Epoch 70, CIFAR-10 Batch 3:  Loss:     0.0602 Validation Accuracy: 0.656600
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.0695 Validation Accuracy: 0.655400
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.0721 Validation Accuracy: 0.649800
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.0668 Validation Accuracy: 0.652600
# Epoch 71, CIFAR-10 Batch 2:  Loss:     0.0420 Validation Accuracy: 0.657200
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.0627 Validation Accuracy: 0.658600
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.0607 Validation Accuracy: 0.652200
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.0673 Validation Accuracy: 0.653800
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.0747 Validation Accuracy: 0.646000
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.0418 Validation Accuracy: 0.657200
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.0597 Validation Accuracy: 0.649800
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.0681 Validation Accuracy: 0.650600
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.0673 Validation Accuracy: 0.648800
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.0617 Validation Accuracy: 0.652400
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.0471 Validation Accuracy: 0.650400
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.0706 Validation Accuracy: 0.653000
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.0836 Validation Accuracy: 0.645600
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.0683 Validation Accuracy: 0.648000
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.0746 Validation Accuracy: 0.658400
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.0507 Validation Accuracy: 0.658200
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.0541 Validation Accuracy: 0.658200
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.0600 Validation Accuracy: 0.650200
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.0640 Validation Accuracy: 0.648000
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.0617 Validation Accuracy: 0.654400
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.0539 Validation Accuracy: 0.650400
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.0631 Validation Accuracy: 0.656400
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.0533 Validation Accuracy: 0.658800
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.0555 Validation Accuracy: 0.655800
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.0583 Validation Accuracy: 0.662800
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.0496 Validation Accuracy: 0.665000
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.0513 Validation Accuracy: 0.657000
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.0517 Validation Accuracy: 0.660000
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.0488 Validation Accuracy: 0.649800
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.0602 Validation Accuracy: 0.657400
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.0429 Validation Accuracy: 0.660200
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.0496 Validation Accuracy: 0.660000
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.0630 Validation Accuracy: 0.642800
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.0512 Validation Accuracy: 0.656400
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.0521 Validation Accuracy: 0.661000
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.0448 Validation Accuracy: 0.659800
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.0534 Validation Accuracy: 0.659600
# Epoch 78, CIFAR-10 Batch 4:  Loss:     0.0398 Validation Accuracy: 0.654600
# Epoch 78, CIFAR-10 Batch 5:  Loss:     0.0543 Validation Accuracy: 0.652200
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.0588 Validation Accuracy: 0.661400
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.0442 Validation Accuracy: 0.656600
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.0425 Validation Accuracy: 0.657600
# Epoch 79, CIFAR-10 Batch 4:  Loss:     0.0446 Validation Accuracy: 0.656000
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.0484 Validation Accuracy: 0.656800
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.0552 Validation Accuracy: 0.652000
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.0390 Validation Accuracy: 0.661400
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.0447 Validation Accuracy: 0.659200
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.0464 Validation Accuracy: 0.651200
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.0463 Validation Accuracy: 0.651600
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.0621 Validation Accuracy: 0.648800
# Epoch 81, CIFAR-10 Batch 2:  Loss:     0.0349 Validation Accuracy: 0.656000
# Epoch 81, CIFAR-10 Batch 3:  Loss:     0.0460 Validation Accuracy: 0.661200
# Epoch 81, CIFAR-10 Batch 4:  Loss:     0.0580 Validation Accuracy: 0.651200
# Epoch 81, CIFAR-10 Batch 5:  Loss:     0.0475 Validation Accuracy: 0.653000
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.0681 Validation Accuracy: 0.650600
# Epoch 82, CIFAR-10 Batch 2:  Loss:     0.0309 Validation Accuracy: 0.660400
# Epoch 82, CIFAR-10 Batch 3:  Loss:     0.0361 Validation Accuracy: 0.659800
# Epoch 82, CIFAR-10 Batch 4:  Loss:     0.0394 Validation Accuracy: 0.652200
# Epoch 82, CIFAR-10 Batch 5:  Loss:     0.0429 Validation Accuracy: 0.651200
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.0456 Validation Accuracy: 0.659400
# Epoch 83, CIFAR-10 Batch 2:  Loss:     0.0300 Validation Accuracy: 0.654000
# Epoch 83, CIFAR-10 Batch 3:  Loss:     0.0497 Validation Accuracy: 0.655000
# Epoch 83, CIFAR-10 Batch 4:  Loss:     0.0411 Validation Accuracy: 0.646600
# Epoch 83, CIFAR-10 Batch 5:  Loss:     0.0513 Validation Accuracy: 0.648200
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.0465 Validation Accuracy: 0.654800
# Epoch 84, CIFAR-10 Batch 2:  Loss:     0.0362 Validation Accuracy: 0.652400
# Epoch 84, CIFAR-10 Batch 3:  Loss:     0.0441 Validation Accuracy: 0.661400
# Epoch 84, CIFAR-10 Batch 4:  Loss:     0.0386 Validation Accuracy: 0.654800
# Epoch 84, CIFAR-10 Batch 5:  Loss:     0.0390 Validation Accuracy: 0.653400
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.0506 Validation Accuracy: 0.657400
# Epoch 85, CIFAR-10 Batch 2:  Loss:     0.0332 Validation Accuracy: 0.653800
# Epoch 85, CIFAR-10 Batch 3:  Loss:     0.0393 Validation Accuracy: 0.663200
# Epoch 85, CIFAR-10 Batch 4:  Loss:     0.0387 Validation Accuracy: 0.652600
# Epoch 85, CIFAR-10 Batch 5:  Loss:     0.0389 Validation Accuracy: 0.655400
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.0429 Validation Accuracy: 0.649800
# Epoch 86, CIFAR-10 Batch 2:  Loss:     0.0306 Validation Accuracy: 0.661600
# Epoch 86, CIFAR-10 Batch 3:  Loss:     0.0452 Validation Accuracy: 0.659000
# Epoch 86, CIFAR-10 Batch 4:  Loss:     0.0424 Validation Accuracy: 0.649400
# Epoch 86, CIFAR-10 Batch 5:  Loss:     0.0395 Validation Accuracy: 0.659600
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.0473 Validation Accuracy: 0.653600
# Epoch 87, CIFAR-10 Batch 2:  Loss:     0.0338 Validation Accuracy: 0.655400
# Epoch 87, CIFAR-10 Batch 3:  Loss:     0.0354 Validation Accuracy: 0.655800
# Epoch 87, CIFAR-10 Batch 4:  Loss:     0.0299 Validation Accuracy: 0.657200
# Epoch 87, CIFAR-10 Batch 5:  Loss:     0.0433 Validation Accuracy: 0.656000
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.0349 Validation Accuracy: 0.649200
# Epoch 88, CIFAR-10 Batch 2:  Loss:     0.0307 Validation Accuracy: 0.651200
# Epoch 88, CIFAR-10 Batch 3:  Loss:     0.0414 Validation Accuracy: 0.653200
# Epoch 88, CIFAR-10 Batch 4:  Loss:     0.0346 Validation Accuracy: 0.648400
# Epoch 88, CIFAR-10 Batch 5:  Loss:     0.0337 Validation Accuracy: 0.648800
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.0384 Validation Accuracy: 0.647600
# Epoch 89, CIFAR-10 Batch 2:  Loss:     0.0251 Validation Accuracy: 0.653400
# Epoch 89, CIFAR-10 Batch 3:  Loss:     0.0443 Validation Accuracy: 0.654200
# Epoch 89, CIFAR-10 Batch 4:  Loss:     0.0428 Validation Accuracy: 0.647000
# Epoch 89, CIFAR-10 Batch 5:  Loss:     0.0386 Validation Accuracy: 0.651400
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.0392 Validation Accuracy: 0.653600
# Epoch 90, CIFAR-10 Batch 2:  Loss:     0.0275 Validation Accuracy: 0.653200
# Epoch 90, CIFAR-10 Batch 3:  Loss:     0.0369 Validation Accuracy: 0.658200
# Epoch 90, CIFAR-10 Batch 4:  Loss:     0.0367 Validation Accuracy: 0.654200
# Epoch 90, CIFAR-10 Batch 5:  Loss:     0.0373 Validation Accuracy: 0.657400
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.0518 Validation Accuracy: 0.646600
# Epoch 91, CIFAR-10 Batch 2:  Loss:     0.0318 Validation Accuracy: 0.654600
# Epoch 91, CIFAR-10 Batch 3:  Loss:     0.0407 Validation Accuracy: 0.649200
# Epoch 91, CIFAR-10 Batch 4:  Loss:     0.0351 Validation Accuracy: 0.645400
# Epoch 91, CIFAR-10 Batch 5:  Loss:     0.0303 Validation Accuracy: 0.654200
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.0447 Validation Accuracy: 0.649200
# Epoch 92, CIFAR-10 Batch 2:  Loss:     0.0302 Validation Accuracy: 0.648600
# Epoch 92, CIFAR-10 Batch 3:  Loss:     0.0311 Validation Accuracy: 0.656000
# Epoch 92, CIFAR-10 Batch 4:  Loss:     0.0389 Validation Accuracy: 0.651400
# Epoch 92, CIFAR-10 Batch 5:  Loss:     0.0349 Validation Accuracy: 0.654400
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.0433 Validation Accuracy: 0.650600
# Epoch 93, CIFAR-10 Batch 2:  Loss:     0.0211 Validation Accuracy: 0.656800
# Epoch 93, CIFAR-10 Batch 3:  Loss:     0.0313 Validation Accuracy: 0.654400
# Epoch 93, CIFAR-10 Batch 4:  Loss:     0.0356 Validation Accuracy: 0.655800
# Epoch 93, CIFAR-10 Batch 5:  Loss:     0.0336 Validation Accuracy: 0.653000
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.0391 Validation Accuracy: 0.653400
# Epoch 94, CIFAR-10 Batch 2:  Loss:     0.0252 Validation Accuracy: 0.651400
# Epoch 94, CIFAR-10 Batch 3:  Loss:     0.0362 Validation Accuracy: 0.658800
# Epoch 94, CIFAR-10 Batch 4:  Loss:     0.0331 Validation Accuracy: 0.651600
# Epoch 94, CIFAR-10 Batch 5:  Loss:     0.0441 Validation Accuracy: 0.653800
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.0338 Validation Accuracy: 0.647000
# Epoch 95, CIFAR-10 Batch 2:  Loss:     0.0175 Validation Accuracy: 0.647600
# Epoch 95, CIFAR-10 Batch 3:  Loss:     0.0353 Validation Accuracy: 0.651400
# Epoch 95, CIFAR-10 Batch 4:  Loss:     0.0374 Validation Accuracy: 0.650400
# Epoch 95, CIFAR-10 Batch 5:  Loss:     0.0306 Validation Accuracy: 0.647800
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.0534 Validation Accuracy: 0.651800
# Epoch 96, CIFAR-10 Batch 2:  Loss:     0.0237 Validation Accuracy: 0.650200
# Epoch 96, CIFAR-10 Batch 3:  Loss:     0.0277 Validation Accuracy: 0.655800
# Epoch 96, CIFAR-10 Batch 4:  Loss:     0.0381 Validation Accuracy: 0.646800
# Epoch 96, CIFAR-10 Batch 5:  Loss:     0.0272 Validation Accuracy: 0.658400
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.0405 Validation Accuracy: 0.646600
# Epoch 97, CIFAR-10 Batch 2:  Loss:     0.0243 Validation Accuracy: 0.649000
# Epoch 97, CIFAR-10 Batch 3:  Loss:     0.0346 Validation Accuracy: 0.658200
# Epoch 97, CIFAR-10 Batch 4:  Loss:     0.0254 Validation Accuracy: 0.646600
# Epoch 97, CIFAR-10 Batch 5:  Loss:     0.0285 Validation Accuracy: 0.658000
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.0368 Validation Accuracy: 0.653600
# Epoch 98, CIFAR-10 Batch 2:  Loss:     0.0188 Validation Accuracy: 0.654400
# Epoch 98, CIFAR-10 Batch 3:  Loss:     0.0307 Validation Accuracy: 0.653800
# Epoch 98, CIFAR-10 Batch 4:  Loss:     0.0276 Validation Accuracy: 0.656400
# Epoch 98, CIFAR-10 Batch 5:  Loss:     0.0328 Validation Accuracy: 0.653000
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.0407 Validation Accuracy: 0.648800
# Epoch 99, CIFAR-10 Batch 2:  Loss:     0.0257 Validation Accuracy: 0.653600
# Epoch 99, CIFAR-10 Batch 3:  Loss:     0.0358 Validation Accuracy: 0.651400
# Epoch 99, CIFAR-10 Batch 4:  Loss:     0.0297 Validation Accuracy: 0.651800
# Epoch 99, CIFAR-10 Batch 5:  Loss:     0.0284 Validation Accuracy: 0.653200
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.0442 Validation Accuracy: 0.644600
# Epoch 100, CIFAR-10 Batch 2:  Loss:     0.0128 Validation Accuracy: 0.651400
# Epoch 100, CIFAR-10 Batch 3:  Loss:     0.0277 Validation Accuracy: 0.650400
# Epoch 100, CIFAR-10 Batch 4:  Loss:     0.0293 Validation Accuracy: 0.643400
# Epoch 100, CIFAR-10 Batch 5:  Loss:     0.0224 Validation Accuracy: 0.653000

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6496999800205231

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
